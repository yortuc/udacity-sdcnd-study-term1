# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    
    # Return the new value for x
    return x - gradx * learning_rate

# %%
"""
Given the starting point of any `x` gradient descent
should be able to find the minimum value of x for the
cost function `f` defined below.
"""
import random

def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x


# Random number better 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# TODO: Set the learning rate
learning_rate = 0.1
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 44302341.000, x = 13312.000
# EPOCH 1: Cost = 28353500.040, x = 10649.600
# EPOCH 2: Cost = 18146241.826, x = 8519.680
# EPOCH 3: Cost = 11613596.568, x = 6815.744
# EPOCH 4: Cost = 7432703.604, x = 5452.595
# EPOCH 5: Cost = 4756932.106, x = 4362.076
# EPOCH 6: Cost = 3044438.348, x = 3489.661
# EPOCH 7: Cost = 1948442.343, x = 2791.729
# EPOCH 8: Cost = 1247004.899, x = 2233.383
# EPOCH 9: Cost = 798084.936, x = 1786.706
# EPOCH 10: Cost = 510776.159, x = 1429.365
# EPOCH 11: Cost = 326898.542, x = 1143.492
# EPOCH 12: Cost = 209216.867, x = 914.794
# EPOCH 13: Cost = 133900.595, x = 731.835
# EPOCH 14: Cost = 85698.181, x = 585.468
# EPOCH 15: Cost = 54848.636, x = 468.374
# EPOCH 16: Cost = 35104.927, x = 374.699
# EPOCH 17: Cost = 22468.953, x = 299.760
# EPOCH 18: Cost = 14381.930, x = 239.808
# EPOCH 19: Cost = 9206.235, x = 191.846
# EPOCH 20: Cost = 5893.791, x = 153.477
# EPOCH 21: Cost = 3773.826, x = 122.782
# EPOCH 22: Cost = 2417.049, x = 98.225
# EPOCH 23: Cost = 1548.711, x = 78.580
# EPOCH 24: Cost = 992.975, x = 62.864
# EPOCH 25: Cost = 637.304, x = 50.291
# EPOCH 26: Cost = 409.675, x = 40.233
# EPOCH 27: Cost = 263.992, x = 32.186
# EPOCH 28: Cost = 170.755, x = 25.749
# EPOCH 29: Cost = 111.083, x = 20.599
# EPOCH 30: Cost = 72.893, x = 16.479
# EPOCH 31: Cost = 48.452, x = 13.184
# EPOCH 32: Cost = 32.809, x = 10.547
# EPOCH 33: Cost = 22.798, x = 8.437
# EPOCH 34: Cost = 16.391, x = 6.750
# EPOCH 35: Cost = 12.290, x = 5.400
# EPOCH 36: Cost = 9.666, x = 4.320
# EPOCH 37: Cost = 7.986, x = 3.456
# EPOCH 38: Cost = 6.911, x = 2.765
# EPOCH 39: Cost = 6.223, x = 2.212
# EPOCH 40: Cost = 5.783, x = 1.769
# EPOCH 41: Cost = 5.501, x = 1.416
# EPOCH 42: Cost = 5.321, x = 1.132
# EPOCH 43: Cost = 5.205, x = 0.906
# EPOCH 44: Cost = 5.131, x = 0.725
# EPOCH 45: Cost = 5.084, x = 0.580
# EPOCH 46: Cost = 5.054, x = 0.464
# EPOCH 47: Cost = 5.034, x = 0.371
# EPOCH 48: Cost = 5.022, x = 0.297
# EPOCH 49: Cost = 5.014, x = 0.237
# EPOCH 50: Cost = 5.009, x = 0.190
# EPOCH 51: Cost = 5.006, x = 0.152
# EPOCH 52: Cost = 5.004, x = 0.122
# EPOCH 53: Cost = 5.002, x = 0.097
# EPOCH 54: Cost = 5.002, x = 0.078
# EPOCH 55: Cost = 5.001, x = 0.062
# EPOCH 56: Cost = 5.001, x = 0.050
# EPOCH 57: Cost = 5.000, x = 0.040
# EPOCH 58: Cost = 5.000, x = 0.032
# EPOCH 59: Cost = 5.000, x = 0.026
# EPOCH 60: Cost = 5.000, x = 0.020
# EPOCH 61: Cost = 5.000, x = 0.016
# EPOCH 62: Cost = 5.000, x = 0.013
# EPOCH 63: Cost = 5.000, x = 0.010
# EPOCH 64: Cost = 5.000, x = 0.008
# EPOCH 65: Cost = 5.000, x = 0.007
# EPOCH 66: Cost = 5.000, x = 0.005
# EPOCH 67: Cost = 5.000, x = 0.004
# EPOCH 68: Cost = 5.000, x = 0.003
# EPOCH 69: Cost = 5.000, x = 0.003
# EPOCH 70: Cost = 5.000, x = 0.002
# EPOCH 71: Cost = 5.000, x = 0.002
# EPOCH 72: Cost = 5.000, x = 0.001
# EPOCH 73: Cost = 5.000, x = 0.001
# EPOCH 74: Cost = 5.000, x = 0.001
# EPOCH 75: Cost = 5.000, x = 0.001
# EPOCH 76: Cost = 5.000, x = 0.001
# EPOCH 77: Cost = 5.000, x = 0.000
# EPOCH 78: Cost = 5.000, x = 0.000
# EPOCH 79: Cost = 5.000, x = 0.000
# EPOCH 80: Cost = 5.000, x = 0.000
# EPOCH 81: Cost = 5.000, x = 0.000
# EPOCH 82: Cost = 5.000, x = 0.000
# EPOCH 83: Cost = 5.000, x = 0.000
# EPOCH 84: Cost = 5.000, x = 0.000
# EPOCH 85: Cost = 5.000, x = 0.000
# EPOCH 86: Cost = 5.000, x = 0.000
# EPOCH 87: Cost = 5.000, x = 0.000
# EPOCH 88: Cost = 5.000, x = 0.000
# EPOCH 89: Cost = 5.000, x = 0.000
# EPOCH 90: Cost = 5.000, x = 0.000
# EPOCH 91: Cost = 5.000, x = 0.000
# EPOCH 92: Cost = 5.000, x = 0.000
# EPOCH 93: Cost = 5.000, x = 0.000
# EPOCH 94: Cost = 5.000, x = 0.000
# EPOCH 95: Cost = 5.000, x = 0.000
# EPOCH 96: Cost = 5.000, x = 0.000
# EPOCH 97: Cost = 5.000, x = 0.000
# EPOCH 98: Cost = 5.000, x = 0.000
# EPOCH 99: Cost = 5.000, x = 0.000
# EPOCH 100: Cost = 5.000, x = 0.000
